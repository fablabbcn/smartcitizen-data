# %%
# %load_ext autoreload
# %autoreload 2
import json

import warnings                                  
warnings.filterwarnings('ignore')

# %%
from src.models.batch import batch_analysis
models_file = '../tasks/iScape.json'
batch_session = batch_analysis(models_file, verbose = True)
# Out:
# Saved updated sensor names and dumped into /Users/macoscar/Documents/04_Projects/02_FabLab/01_SmartCitizen/01_Repositories/DataAnalysis/smartcitizen-iscape-data/data/interim/sensorNames.json
# Object initialised successfully

# %%
batch_session.run()
# Out:
# Evaluating task PROCESS_ISCAPE_W_DELTAS
# No model involved in task PROCESS_ISCAPE_W_DELTAS
# Loading data...
# Test Load
# Loading test 2019-06_EXT_HASSELT_SCHOOL
# HASSELT TEST IN SCHOOL The device is installed at the main entrance of the school at about 2.5-meter height. The address of the school is Joris van Oostenrijkstraat 34, 3511 Hasselt.
# Air quality in the school in summer vacations and regular period. Plan to monitor the air quality for 2 months of vacation period i.e July and August and 1 month of the regular period i.e. September. Station 9530 was deployed at the  2nd-floor apartment of a residential building near a busy road intersection. Only the station 9694 is covered with the umbrella as it is open to the sky
# Device ID 9530
# Loaded cached files from:
# /Users/macoscar/Documents/04_Projects/02_FabLab/01_SmartCitizen/01_Repositories/DataAnalysis/smartcitizen-iscape-data/data/processed/2019/06/2019-06_EXT_HASSELT_SCHOOL/cached/9530.csv
# ...
