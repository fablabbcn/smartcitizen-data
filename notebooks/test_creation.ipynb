# %% [markdown]
# This notebook will create the necessary folder structure for later use in the data_analysis notebook.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Input data below

# %%
from src.data.test import test
import pandas as pd

#----
isnewtest = False # Is new test or a test to be updated
date = '2019-06-19'
who = 'INT'
short_name = 'MUV_CORRELATION_TEST_STATION_21_CSIC'
comment = '''Co-location of the Station V2.1 in CSIC with 12 MUV Stations - MUV Project'''
#----

# Create test object
newtest = test(pd.to_datetime(date).strftime('%Y-%m') + '_' + who + '_' + short_name, pd.to_datetime(date), new = isnewtest)

# Add General test details
newtest.add_details(project = 'smartcitizen', 
                     commit = 'various', 
                     author = 'Guillem-Oscar', 
                     type_test = 'outdoor', 
                     report = '', 
                     comment = comment)

newtest.add_device('MUV_1340424',
                device_type = 'Other', 
                location = 'Europe/Madrid',
                device_files = {'fileNameRaw': 'MUV_1340424.csv', 
                                  'fileNameInfo': '', 
                                  'frequency': '3Min',
                                  'source': 'csv_old'})        


newtest.add_device('MUV_1340511', 
				device_type = 'Other', 
                location = 'Europe/Madrid',
                device_files = {'fileNameRaw': 'MUV_1340511.csv',
                				'fileNameInfo': '',
                				'frequency': '3Min',
                				'source': 'csv_old'})
                				
newtest.add_device('MUV_5801167',
				device_type = 'Other', 
                location = 'Europe/Madrid',
                device_files = {'fileNameRaw': 'MUV_5801167.csv',
                				'fileNameInfo': '',
                				'frequency': '3Min',
                				'source': 'csv_old'})
                				
newtest.add_device('MUV_5799871',
				device_type = 'Other', 
                location = 'Europe/Madrid',
                device_files = {'fileNameRaw': 'MUV_5799871.csv',
                				'fileNameInfo': '',
                				'frequency': '3Min',
                				'source': 'csv_old'})
                				
newtest.add_device('MUV_5801118',
				device_type = 'Other', 
                location = 'Europe/Madrid',
                device_files = {'fileNameRaw': 'MUV_5801118.csv',
                				'fileNameInfo': '',
                				'frequency': '3Min',
                				'source': 'csv_old'})
                				
newtest.add_device('MUV_5800177',
				device_type = 'Other', 
                location = 'Europe/Madrid',
                device_files = {'fileNameRaw': 'MUV_5800177.csv',
                				'fileNameInfo': '',
                				'frequency': '3Min',
                				'source': 'csv_old'})
                				
newtest.add_device('MUV_5801988',
				device_type = 'Other', 
                location = 'Europe/Madrid',
                device_files = {'fileNameRaw': 'MUV_5801988.csv',
                				'fileNameInfo': '',
                				'frequency': '3Min',
                				'source': 'csv_old'})
                				
newtest.add_device('MUV_5802283',
				device_type = 'Other', 
                location = 'Europe/Madrid',
                device_files = {'fileNameRaw': 'MUV_5802283.csv',
                				'fileNameInfo': '',
                				'frequency': '3Min',
                				'source': 'csv_old'})
                				
newtest.add_device('MUV_1340722',
				device_type = 'Other', 
                location = 'Europe/Madrid',
                device_files = {'fileNameRaw': 'MUV_1340722.csv',
                				'fileNameInfo': '',
                				'frequency': '3Min',
                				'source': 'csv_old'})
                				
newtest.add_device('MUV_5801123',
				device_type = 'STATION', 
                location = 'Europe/Madrid',
                device_files = {'fileNameRaw': 'MUV_5801123.csv',
                				'fileNameInfo': '',
                				'frequency': '3Min',
                				'source': 'csv_old'})
                				
newtest.add_device('MUV_5800147',
				device_type = 'STATION', 
                location = 'Europe/Madrid',
                device_files = {'fileNameRaw': 'MUV_5800147.csv',
                				'fileNameInfo': '',
                				'frequency': '3Min',
                				'source': 'csv_old'})
                				
newtest.add_device('MUV_5800390',
				device_type = 'Other', 
                location = 'Europe/Madrid',
                device_files = {'fileNameRaw': 'MUV_5800390.csv',
                				'fileNameInfo': '',
                				'frequency': '3Min',
                				'source': 'csv_old'})
                				
# newtest.add_device('STATION_9441',
#                    device_type = 'STATION',
#                    location = 'Europe/Madrid',
#                    pm_sensor = 'PMS5003',
#                    device_history = '9441',
#                    device_files = {'device_id': '9441', 
#                                    'frequency': '1Min',
#                                    'source': 'api',
#                                     'min_date': '2019-06-01',
#                                     'max_date': None})

# Process the stuff
newtest.process_files()
# Out:
# Loading yaml file from...
# 	/Users/macoscar/Documents/04_Projects/02_FabLab/01_SmartCitizen/01_Repositories/DataAnalysis/smartcitizen-iscape-data/data/interim
# Updating test...
# Add details...
# 	OK
# Add device MUV_1340424...
# 	OK
# Add device files MUV_1340424...
# 	OK
# Add device MUV_1340511...
# 	OK
# Add device files MUV_1340511...
# 	OK
# Add device MUV_5801167...
# 	OK
# Add device files MUV_5801167...
# 	OK
# Add device MUV_5799871...
# 	OK
# Add device files MUV_5799871...
# 	OK
# Add device MUV_5801118...
# 	OK
# Add device files MUV_5801118...
# 	OK
# Add device MUV_5800177...
# 	OK
# Add device files MUV_5800177...
# 	OK
# Add device MUV_5801988...
# 	OK
# Add device files MUV_5801988...
# 	OK
# Add device MUV_5802283...
# 	OK
# Add device files MUV_5802283...
# 	OK
# Add device MUV_1340722...
# 	OK
# Add device files MUV_1340722...
# 	OK
# Add device MUV_5801123...
# 	OK
# Add device files MUV_5801123...
# 	OK
# Add device MUV_5800147...
# 	OK
# Add device files MUV_5800147...
# 	OK
# Add device MUV_5800390...
# 	OK
# Add device files MUV_5800390...
# 	OK
# Processing files...
# Copy raw files...
# 	OK
# Processing csv from device MUV_1340424
# 	No txt info available
# Processing csv from device MUV_1340511
# 	No txt info available
# Processing csv from device MUV_1340722
# 	No txt info available
# Processing csv from device MUV_5799871
# 	No txt info available
# Processing csv from device MUV_5800147
# 	No txt info available
# Processing csv from device MUV_5800177
# 	No txt info available
# Processing csv from device MUV_5800390
# 	No txt info available
# Processing csv from device MUV_5801118
# 	No txt info available
# Processing csv from device MUV_5801123
# 	No txt info available
# Processing csv from device MUV_5801167
# 	No txt info available
# Processing csv from device MUV_5801988
# 	No txt info available
# Processing csv from device MUV_5802283
# 	No txt info available
# Test Update Finished

# %%
# ----------------------------------
# Examples
# ----------------------------------
# Add Device (as many as needed)
# Devices can be sourced from a csv file or from the API
# ['source']: either 'csv_old', 'csv_new' or 'api'
# CSV: 
#    - ['fileNameRaw']: file name of the csv containing the data
#    - ['fileNameInfo']: file name of the info
#    - ['frequency']: frequency of the data
#  API:
#    - ['device_id']: platform device ID
#    - ['frequency']: target frequency of the data
#    - ['min_date']: min_date (can be None and it will get from the first)
#    - ['max_date']: max_date (can be None and it will update till the latest)
# If the device is in the history, it can be directly referenced. If not, you can specify a dictionary (alphasense, with slots and IDs)
# ----------------------------------
# Example of csv device with old csv
# ----------------------------------
#test.add_device('5527', 
#                device_type = 'STATION', 
#                sck_version = '2.0', 
#                pm_sensor = 'none', 
#                device_history = '5527',
#                location = 'Europe/London',
#                device_files = {'fileNameRaw': '5261.csv', 
#                                  'fileNameInfo': '', 
#                                  'frequency': '1Min',
#                                  'source': 'csv_old'})
# ----------------------------------
# Example of device from API with alphasense data
# ----------------------------------
# test.add_device('5565', 
#                 device_type = 'STATION', 
#                 sck_version = '2.0', 
#                 pm_sensor = 'none',
#                 alphasense = {'CO': 162581708,
#                               'NO2': 202160421,
#                               'O3': 204160144,
#                               'slots': ['CO', 'NO2', 'O3']
#                              },
#                 location = 'Europe/Dublin',
#                 device_files = {'device_id': '5265', 
#                                   'frequency': '1Min',
#                                   'source': 'api',
#                                    'min_date': '2019-02-01',
#                                    'max_date': None})
#
# ----------------------------------
# Example of reference device with 15' frequency
# ----------------------------------
# test.add_reference('CITY_COUNCIL', 
#                   fileNameRaw = 'CITY_COUNCIL.csv', 
#                   index = {'name' : 'Time',
#                            'format' : '%Y-%m-%d %H:%M:%S',
#                            'frequency' : '15Min'}, 
#                   channels = {'pollutants' : ('CO', 'SO2', 'NO2', 'NO', 'NOX'), 
#                               'units' : ('ppm', 'ppb', 'ppb', 'ppb', 'ppb'),
#                               'names' : ('CO_ppm', 'SO2_ppb', 'NO2_ppb', 'NO_ppb', 'NOx_ppb')
#                              },
#                   location = 'Europe/Dublin')
#
# ----------------------------------
# Example of reference device with 1D frequency
# ----------------------------------
# test.add_reference('CITY_COUNCIL_DAY', 
#                   fileNameRaw = 'CITY_COUNCIL_DAY.csv', 
#                   index = {'name' : 'Time',
#                            'format' : '%d/%m/%Y',
#                            'frequency' : '1D'}, 
#                   channels = {'pollutants' : ['PM10'], 
#                               'units' : ['ugm3'],
#                               'names' : ['PM10']
#                              },
#                   location = 'Europe/Dublin')
