# %% [markdown]
# This notebook will create the necessary folder structure for later use in the data_analysis notebook. Run this cell first.

# %%
# %load_ext autoreload
# %autoreload 2
from src.data.test_tools import test
import pandas as pd

# %% [markdown]
# ## Test information

# %%
#----
# Is you are creating a new test (True) or if the test is going to be updated (False)
isnewtest = True
# Date when you performed the test in 'YYYY-MM-DD' format
date = '2019-09-04'
# INTernal or EXTernal test (made by your organisation or others)
who = 'EXT' 
# Short title for the test
short_name = 'DECODE'
# Comment for your test. Make this as long as you need to describe fully the purpose of this test
comment = '''DECODE KITS'''
# Project
project = 'SmartCitizen'
# Firmware version
commit = ''
# Who made the test
author = 'Oscar'
# Test type (indoor, outdoor, anything that helps you organise later on)
type_test = ''
# If you are going to document the results somewhere, you can put a link below
report = ''
#----

# Create test object
newtest = test(pd.to_datetime(date).strftime('%Y-%m') + '_' + who + '_' + short_name, pd.to_datetime(date), new = isnewtest)

# Add General test details
newtest.add_details(project = project, 
                     commit = commit, 
                     author = author, 
                     type_test = type_test, 
                     report = report, 
                     comment = comment)
# Out:
# Loading yaml file from...
# 	/Users/macoscar/Documents/04_Projects/02_FabLab/01_SmartCitizen/01_Repositories/DataAnalysis/smartcitizen-iscape-data/data/interim
# Creating new test...
# Add details...
# OK
# /Users/macoscar/Documents/04_Projects/02_FabLab/01_SmartCitizen/01_Repositories/DataAnalysis/smartcitizen-iscape-data/src/data/test_tools.py:118: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   sensorsData = yaml.load(yml)

# %% [markdown]
# ## Add devices

# %%
newtest.add_device("9421",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9421", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9422",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9422", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9423",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9423", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9436",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9436", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9442",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9442", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9443",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9443", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9445",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9445", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9472",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9472", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9474",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9474", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9523",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9523", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9524",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9524", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9591",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9591", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9661",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9661", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9667",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9667", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9669",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9669", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9670",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9670", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9672",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9672", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9673",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9673", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9674",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9674", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9676",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9676", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9677",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9677", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9678",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9678", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9679",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9679", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9680",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9680", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9682",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9682", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9686",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9686", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9687",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9687", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9690",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9690", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9692",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9692", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9693",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9693", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9696",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9696", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9700",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9700", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9701",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9701", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9702",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9702", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9753",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9753", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9764",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9764", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
                                   
newtest.add_device("9765",device_type = 'KIT',
                   location = 'Europe/London',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9765", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': '2019-07-01',
                                   'max_date': None})
# Out:
# Add device 9421...
# 	OK
# Add device files 9421...
# OK
# Add device 9422...
# 	OK
# Add device files 9422...
# OK
# Add device 9423...
# 	OK
# Add device files 9423...
# OK
# Add device 9436...
# 	OK
# Add device files 9436...
# OK
# Add device 9442...
# 	OK
# Add device files 9442...
# OK
# Add device 9443...
# 	OK
# Add device files 9443...
# OK
# Add device 9445...
# 	OK
# Add device files 9445...
# OK
# Add device 9472...
# 	OK
# Add device files 9472...
# OK
# Add device 9474...
# 	OK
# Add device files 9474...
# OK
# Add device 9523...
# 	OK
# Add device files 9523...
# OK
# Add device 9524...
# 	OK
# Add device files 9524...
# OK
# Add device 9591...
# 	OK
# Add device files 9591...
# OK
# Add device 9661...
# 	OK
# Add device files 9661...
# OK
# Add device 9667...
# 	OK
# Add device files 9667...
# OK
# Add device 9669...
# 	OK
# Add device files 9669...
# OK
# Add device 9670...
# 	OK
# Add device files 9670...
# OK
# Add device 9672...
# 	OK
# Add device files 9672...
# ...

# %% [markdown]
# ## Process the test

# %%
# Process the stuff
newtest.process_files()
# Out:
# Processing files...
# Copy raw files...
# 	OK
# Test Creation Finished

# %%
# ----------------------------------
# Examples
# ----------------------------------
# Add Device (as many as needed)
# Devices can be sourced from a csv file or from the API
# ['source']: either 'csv_old', 'csv_new' or 'api'
# CSV: 
#    - ['fileNameRaw']: file name of the csv containing the data
#    - ['fileNameInfo']: file name of the info
#    - ['frequency']: frequency of the data
#  API:
#    - ['device_id']: platform device ID
#    - ['frequency']: target frequency of the data
#    - ['min_date']: min_date (can be None and it will get from the first)
#    - ['max_date']: max_date (can be None and it will update till the latest)
# If the device is in the history, it can be directly referenced. If not, you can specify a dictionary (alphasense, with slots and IDs)
# ----------------------------------
# Example of csv device with old csv
# ----------------------------------
#newtest.add_device('5527', 
#                device_type = 'STATION', 
#                sck_version = '2.0', 
#                pm_sensor = 'none', 
#                device_history = '5527',
#                location = 'Europe/London',
#                device_files = {'fileNameRaw': '5261.csv', 
#                                  'fileNameInfo': '', 
#                                  'frequency': '1Min',
#                                  'source': 'csv_old'})
# ----------------------------------
# Example of device from API with alphasense data
# ----------------------------------
# newtest.add_device('5565', 
#                 device_type = 'STATION', 
#                 sck_version = '2.0', 
#                 pm_sensor = 'none',
#                 alphasense = {'CO': 162581708,
#                               'NO2': 202160421,
#                               'O3': 204160144,
#                               'slots': ['CO', 'NO2', 'O3']
#                              },
#                 location = 'Europe/Dublin',
#                 device_files = {'device_id': '5265', 
#                                   'frequency': '1Min',
#                                   'source': 'api',
#                                    'min_date': '2019-02-01',
#                                    'max_date': None})
# ----------------------------------
# Example of device from API in history
# ----------------------------------
# newtest.add_device('8739',
#                    device_type = 'STATION',
#                    location = 'Europe/London',
#                    pm_sensor = 'PMS5003',
#                    device_history = '8739',
#                    device_files = {'device_id': '8739', 
#                                    'frequency': '1Min',
#                                    'source': 'api',
#                                    'min_date': '2019-06-18',
#                                    'max_date': None})
#
# ----------------------------------
# Example of reference device with 15' frequency
# ----------------------------------
# newtest.add_reference('CITY_COUNCIL', 
#                   fileNameRaw = 'CITY_COUNCIL.csv', 
#                   index = {'name' : 'Time',
#                            'format' : '%Y-%m-%d %H:%M:%S',
#                            'frequency' : '15Min'}, 
#                   channels = {'pollutants' : ('CO', 'SO2', 'NO2', 'NO', 'NOX'), 
#                               'units' : ('ppm', 'ppb', 'ppb', 'ppb', 'ppb'),
#                               'names' : ('CO_ppm', 'SO2_ppb', 'NO2_ppb', 'NO_ppb', 'NOx_ppb')
#                              },
#                   location = 'Europe/Dublin')
#
# ----------------------------------
# Example of reference device with 1D frequency
# ----------------------------------
# test.add_reference('CITY_COUNCIL_DAY', 
#                   fileNameRaw = 'CITY_COUNCIL_DAY.csv', 
#                   index = {'name' : 'Time',
#                            'format' : '%d/%m/%Y',
#                            'frequency' : '1D'}, 
#                   channels = {'pollutants' : ['PM10'], 
#                               'units' : ['ugm3'],
#                               'names' : ['PM10']
#                              },
#                   location = 'Europe/Dublin')
