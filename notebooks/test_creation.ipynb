# %% [markdown]
# This notebook will create the necessary folder structure for later use in the data_analysis notebook. Run this cell first.

# %%
# %load_ext autoreload
# %autoreload 2
from src.data.test_tools import test
import pandas as pd

# %% [markdown]
# ## Test information

# %%
#----
# Is you are creating a new test (True) or if the test is going to be updated (False)
isnewtest = True
# Date when you performed the test in 'YYYY-MM-DD' format
date = '2019-09-09'
# INTernal or EXTernal test (made by your organisation or others)
who = 'INT' 
# Short title for the test
short_name = 'DELIVERIES_SEPTEMBER'
# Comment for your test. Make this as long as you need to describe fully the purpose of this test
comment = '''Deliveries september'''
# Project
project = 'Grow, iScape, external'
# Firmware version
commit = ''
# Who made the test
author = 'Oscar'
# Test type (indoor, outdoor, anything that helps you organise later on)
type_test = ''
# If you are going to document the results somewhere, you can put a link below
report = ''
#----

# Create test object
newtest = test(pd.to_datetime(date).strftime('%Y-%m') + '_' + who + '_' + short_name, pd.to_datetime(date), new = isnewtest)

# Add General test details
newtest.add_details(project = project, 
                     commit = commit, 
                     author = author, 
                     type_test = type_test, 
                     report = report, 
                     comment = comment)
# Out:
# Loading yaml file from...
# 	/Users/macoscar/Documents/04_Projects/02_FabLab/01_SmartCitizen/01_Repositories/DataAnalysis/smartcitizen-iscape-data/data/interim
# Creating new test...
# Add details...
# OK
# /Users/macoscar/Documents/04_Projects/02_FabLab/01_SmartCitizen/01_Repositories/DataAnalysis/smartcitizen-iscape-data/src/data/test_tools.py:118: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   sensorsData = yaml.load(yml)

# %% [markdown]
# ## Add devices

# %%
newtest.add_device("9964",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9964", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9965",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9965", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9966",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9966", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9967",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9967", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9968",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9968", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9969",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9969", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9970",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9970", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9971",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9971", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9972",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9972", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9973",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9973", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9974",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9974", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9975",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9975", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9976",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9976", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9977",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9977", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9978",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9978", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9979",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9979", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9980",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9980", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9981",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9981", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9982",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9982", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9983",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9983", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9984",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9984", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9985",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9985", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9986",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9986", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9987",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9987", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
newtest.add_device("9988",device_type = 'KIT',
                   location = 'Europe/Madrid',
                   pm_sensor = 'PMS5003', 
                   device_files = {'device_id': "9988", 
                                   'frequency': '1Min',
                                   'source': 'api',
                                   'min_date': None,
                                   'max_date': None})
# Out:
# Add device 9964...
# 	OK
# Add device files 9964...
# OK
# Add device 9965...
# 	OK
# Add device files 9965...
# OK
# Add device 9966...
# 	OK
# Add device files 9966...
# OK
# Add device 9967...
# 	OK
# Add device files 9967...
# OK
# Add device 9968...
# 	OK
# Add device files 9968...
# OK
# Add device 9969...
# 	OK
# Add device files 9969...
# OK
# Add device 9970...
# 	OK
# Add device files 9970...
# OK
# Add device 9971...
# 	OK
# Add device files 9971...
# OK
# Add device 9972...
# 	OK
# Add device files 9972...
# OK
# Add device 9973...
# 	OK
# Add device files 9973...
# OK
# Add device 9974...
# 	OK
# Add device files 9974...
# OK
# Add device 9975...
# 	OK
# Add device files 9975...
# OK
# Add device 9976...
# 	OK
# Add device files 9976...
# OK
# Add device 9977...
# 	OK
# Add device files 9977...
# OK
# Add device 9978...
# 	OK
# Add device files 9978...
# OK
# Add device 9979...
# 	OK
# Add device files 9979...
# OK
# Add device 9980...
# 	OK
# Add device files 9980...
# OK
# Add device 9981...
# 	OK
# Add device files 9981...
# OK
# Add device 9982...
# 	OK
# Add device files 9982...
# OK
# Add device 9983...
# 	OK
# Add device files 9983...
# OK
# Add device 9984...
# 	OK
# Add device files 9984...
# OK
# Add device 9985...
# 	OK
# Add device files 9985...
# OK
# Add device 9986...
# 	OK
# Add device files 9986...
# OK
# Add device 9987...
# 	OK
# Add device files 9987...
# OK
# Add device 9988...
# 	OK
# Add device files 9988...
# OK

# %% [markdown]
# ## Process the test

# %%
# Process the stuff
newtest.process_files()
# Out:
# Processing files...
# Copy raw files...
# 	OK
# Test Creation Finished

# %%
# ----------------------------------
# Examples
# ----------------------------------
# Add Device (as many as needed)
# Devices can be sourced from a csv file or from the API
# ['source']: either 'csv_old', 'csv_new' or 'api'
# CSV: 
#    - ['fileNameRaw']: file name of the csv containing the data
#    - ['fileNameInfo']: file name of the info
#    - ['frequency']: frequency of the data
#  API:
#    - ['device_id']: platform device ID
#    - ['frequency']: target frequency of the data
#    - ['min_date']: min_date (can be None and it will get from the first)
#    - ['max_date']: max_date (can be None and it will update till the latest)
# If the device is in the history, it can be directly referenced. If not, you can specify a dictionary (alphasense, with slots and IDs)
# ----------------------------------
# Example of csv device with old csv
# ----------------------------------
#newtest.add_device('5527', 
#                device_type = 'STATION', 
#                sck_version = '2.0', 
#                pm_sensor = 'none', 
#                device_history = '5527',
#                location = 'Europe/London',
#                device_files = {'fileNameRaw': '5261.csv', 
#                                  'fileNameInfo': '', 
#                                  'frequency': '1Min',
#                                  'source': 'csv_old'})
# ----------------------------------
# Example of device from API with alphasense data
# ----------------------------------
# newtest.add_device('5565', 
#                 device_type = 'STATION', 
#                 sck_version = '2.0', 
#                 pm_sensor = 'none',
#                 alphasense = {'CO': 162581708,
#                               'NO2': 202160421,
#                               'O3': 204160144,
#                               'slots': ['CO', 'NO2', 'O3']
#                              },
#                 location = 'Europe/Dublin',
#                 device_files = {'device_id': '5265', 
#                                   'frequency': '1Min',
#                                   'source': 'api',
#                                    'min_date': '2019-02-01',
#                                    'max_date': None})
# ----------------------------------
# Example of device from API in history
# ----------------------------------
# newtest.add_device('8739',
#                    device_type = 'STATION',
#                    location = 'Europe/London',
#                    pm_sensor = 'PMS5003',
#                    device_history = '8739',
#                    device_files = {'device_id': '8739', 
#                                    'frequency': '1Min',
#                                    'source': 'api',
#                                    'min_date': '2019-06-18',
#                                    'max_date': None})
#
# ----------------------------------
# Example of reference device with 15' frequency
# ----------------------------------
# newtest.add_reference('CITY_COUNCIL', 
#                   fileNameRaw = 'CITY_COUNCIL.csv', 
#                   index = {'name' : 'Time',
#                            'format' : '%Y-%m-%d %H:%M:%S',
#                            'frequency' : '15Min'}, 
#                   channels = {'pollutants' : ('CO', 'SO2', 'NO2', 'NO', 'NOX'), 
#                               'units' : ('ppm', 'ppb', 'ppb', 'ppb', 'ppb'),
#                               'names' : ('CO_ppm', 'SO2_ppb', 'NO2_ppb', 'NO_ppb', 'NOx_ppb')
#                              },
#                   location = 'Europe/Dublin')
#
# ----------------------------------
# Example of reference device with 1D frequency
# ----------------------------------
# test.add_reference('CITY_COUNCIL_DAY', 
#                   fileNameRaw = 'CITY_COUNCIL_DAY.csv', 
#                   index = {'name' : 'Time',
#                            'format' : '%d/%m/%Y',
#                            'frequency' : '1D'}, 
#                   channels = {'pollutants' : ['PM10'], 
#                               'units' : ['ugm3'],
#                               'names' : ['PM10']
#                              },
#                   location = 'Europe/Dublin')
